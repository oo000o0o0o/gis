# %%
import folium
from folium import plugins
import geopandas as gpd
import pandas as pd
import contextily as ctx
import plotly.express as px
import contextily as cx
import numpy as np
import matplotlib.pyplot as plt


# set font
import matplotlib as mpl

# for Mac
# mpl.rc('font',family='Hiragino Maru Gothic Pro')

# for PC
mpl.rc('font',family='MS Gothic')

# %%
# 空間データなので geopandas (gpd) でインポート

#chibamesh1 = gpd.read_file('data/SDDSWS5239.zip')
#chibamesh2 = gpd.read_file('data/SDDSWS5240.zip')
#chibamesh3 = gpd.read_file('data/SDDSWS5339.zip')
#chibamesh4 = gpd.read_file('data/SDDSWS5340.zip')

# %%
# combine all four mesh shapes
#chibamesh = gpd.pd.concat([chibamesh1,chibamesh2,chibamesh3,chibamesh4])

# %%
data1 = pd.read_csv('data/COVID-custom8-2.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data1 = pd.read_csv('data/COVID-custom8-2.csv')
#
# File c:\Users\nishi\miniconda3\envs\gis\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\nishi\miniconda3\envs\gis\Lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File c:\Users\nishi\miniconda3\envs\gis\Lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\nishi\miniconda3\envs\gis\Lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File c:\Users\nishi\miniconda3\envs\gis\Lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/COVID-custom8-2.csv'

# %%
data1
# Out:
#             ID  age  Gender   longitude   latitude   infection  Gender.1
# 0            1   30    Male  139.642347  35.447504   2020/1/15         1  \
# 1            2   40    Male  116.409685  39.903832   2020/1/24         1
# 2            3   30  Female  116.409685  39.903832   2020/1/25         0
# 3            4   40    Male  116.409685  39.903832   2020/1/26         1
# 4            5   40    Male  116.409685  39.903832   2020/1/28         1
# ...        ...  ...     ...         ...        ...         ...       ...
# 124874  133170   30    Male  138.412868  36.744750  2020/11/30         1
# 124875  133171   70  Female  138.440643  36.922904  2020/11/30         0
# 124876  133172   70  Female  137.851094  36.503017  2020/11/30         0
# 124877  133173   50    Male  137.851094  36.503017  2020/11/30         1
# 124878  133174   60  Female  138.114709  36.530777  2020/11/30         0
#
#         month  day
# 0           1   15
# 1           1   24
# 2           1   25
# 3           1   26
# 4           1   28
# ...       ...  ...
# 124874     11   30
# 124875     11   30
# 124876     11   30
# 124877     11   30
# 124878     11   30
#
# [124879 rows x 9 columns]

# %%
# get center lat/lon
center_lat = data1['latitude'].mean()
center_lon = data1['longitude'].mean()

print(center_lat,center_lon)
# Out:
# 35.24261591247848 137.59804835384338

# %%
35.689294093556576, 139.691859387526

# %%
male = data1[data1['Gender']=='Male']
female = data1[data1['Gender']=='Female']

m1 = data1[data1['month']==1]
m2 = data1[data1['month']==2]
m3 = data1[data1['month']==3]
m4 = data1[data1['month']==4]
m5 = data1[data1['month']==5]
m6 = data1[data1['month']==6]
m7 = data1[data1['month']==7]
m8 = data1[data1['month']==8]
m9 = data1[data1['month']==9]
m10 = data1[data1['month']==10]
m11= data1[data1['month']==11]
m12= data1[data1['month']==12]

Wshin_lat = 35.689294093556576
Wshin_lon = 139.691859387526

# %%
# make the map
# m = folium.Map(location=[center_lat,center_lon], zoom_start=8)
m = folium.Map(location=[Wshin_lat,Wshin_lon], zoom_start=13)
group = plugins.MarkerCluster().add_to(m)

# df をループしてマーカーを作る
for index, row in m3.iterrows():
    latlon = [row['latitude'],row['longitude']]
    folium.Marker(latlon, 
                  popup='<div style="width:350px">'+row['infection']+'</div>', 
                  tooltip=row['infection'],
                  
                ).add_to(group)
    
for index, row in m2.iterrows():
    latlon = [row['latitude'],row['longitude']]
    folium.Marker(latlon, 
                  popup='<div style="width:350px">'+row['infection']+'</div>', 
                  tooltip=row['infection'],
                  
                ).add_to(group)

for index, row in m1.iterrows():
    latlon = [row['latitude'],row['longitude']]
    folium.Marker(latlon, 
                  popup='<div style="width:350px">'+row['infection']+'</div>', 
                  tooltip=row['infection'],
                  
                ).add_to(group)

# show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ebaeeafce3ca08da4802c0af1593c120 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ebaeeafce3ca08da4802c0af1593c120&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ebaeeafce3ca08da4802c0af1593c120 = L.map(
#                 &quot;map_ebaeeafce3ca08da4802c0af1593c120&quot;,
#                 {
#                     center: [35.689294093556576, 139.691859387526],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e6b71212585d4b1aa098c5b96cbfc60e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ebaeeafce3ca08da4802c0af1593c120);
#
#
#             var marker_cluster_097a0e0eb0de506744ff9e99592ffab8 = L.markerClusterGroup(
#                 {}
#             );
#             map_ebaeeafce3ca08da4802c0af1593c120.addLayer(marker_cluster_097a0e0eb0de506744ff9e99592ffab8);
#
#
#             var marker_a3096dfb01cd0f2bf97897c3969c602b = L.marker(
#                 [33.880876, 130.873424],
#                 {}
#             ).addTo(marker_cluster_097a0e0eb0de506744ff9e99592ffab8);
#
#
#         var popup_3cad60e90e7aa8654aea1b17edc761ad = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cfb40022abd90cf1d4fba8e8172beba5 = $(`&lt;div id=&quot;html_cfb40022abd90cf1d4fba8e8172beba5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:350px&quot;&gt;2020/3/1&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_3cad60e90e7aa8654aea1b17edc761ad.setContent(html_cfb40022abd90cf1d4fba8e8172beba5);
#
#
#
#         marker_a3096dfb01cd0f2bf97897c3969c602b.bindPopup(popup_3cad60e90e7aa8654aea1b17edc761ad)
#         ;
#
#
#
#
#             marker_a3096dfb01cd0f2bf97897c3969c602b.bindTooltip(
#                 `&lt;div&gt;
#                      2020/3/1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_00fa8564639c521c79e06b661ca336c0 = L.marker(
#                 [35.69448, 139.982454],
#                 {}
#             ).addTo(marker_cluster_097a0e0eb0de506744ff9e99592ffab8);
#
#
#         var popup_70588d814ec4af172f61ce7895c9c232 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3e6a43e24edce733cf291bec4d7a5ad9 = $(`&lt;div id=&quot;html_3e6a43e24edce733cf291bec4d7a5ad9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:350px&quot;&gt;2020/3/1&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_70588d814ec4af172f61ce7895c9c232.setContent(html_3e6a43e24edce733cf291bec4d7a5ad9);
#
#
#
#         marker_00fa8564639c521c79e06b661ca336c0.bindPopup(popup_70588d814ec4af172f61ce7895c9c232)
#         ;
#
#
#
#
#             marker_00fa8564639c521c79e06b661ca336c0.bindTooltip(
#                 `&lt;div&gt;
#                      2020/3/1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_09f1aae496cf9f6791d19d775cfcf550 = L.marker(
#                 [43.103746, 141.536246],
#                 {}
#             ).addTo(marker_cluster_097a0e0eb0de506744ff9e99592ffab8);
#
#
#         var popup_51df235954ad1b7ae0c1472e00dc8ef4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f6b3d2a28d76f494abd8d25923b4c5ea = $(`&lt;div id=&quot;html_f6b3d2a28d76f494abd8d25923b4c5ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:350px&quot;&gt;2020/3/1&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_51df235954ad1b7ae0c1472e00dc8ef4.setContent(html_f6b3d2a28d76f494abd8d25923b4c5ea);
#
#
#
#         marker_09f1aae496cf9f6791d19d775cfcf550.bindPopup(popup_51df235954ad1b7ae0c1472e00dc8ef4)
#         ;
#
#
#
#
#             marker_09f1aae496cf9f6791d19d775cfcf550.bindTooltip(
#                 `&lt;div&gt;
#                      2020/3/1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_79230cb12ebeff82df0c01ea53eff66f = L.marker(
#                 [43.804031, 143.895876],
#                 {}
#             )

# %%
# check data info
data1.info()

# %%
data1.columns

# %%
data1.columns[1:]

# %%
# 元のデータを入れ替える
#data1[data1.columns[1:]]=data1[data1.columns[1:]].astype(float)

# %%
data1 =
