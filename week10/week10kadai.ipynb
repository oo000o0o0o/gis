# %%
import geopandas as gpd
import pandas as pd
import contextily as ctx
import plotly.express as px
import contextily as cx
import numpy as np

# set font
import matplotlib as mpl

# for Mac
 # mpl.rc('font',family='Hiragino Maru Gothic Pro')

# for PC
mpl.rc('font',family='MS Gothic')

# %%
gnmmesh1 = gpd.read_file('data/SDDSWS5940.zip')
gummesh2 = gpd.read_file('data/SDDSWS6040.zip')

# %%
gumamesh = gpd.pd.concat([gnmmesh1,gummesh2])

# %%
gumamesh.head()
# Out:
#    KEY_CODE MESH1_ID MESH2_ID MESH3_ID  OBJ_ID
# 0  59400000     5940       00       00       1  \
# 1  59400001     5940       00       01       2
# 2  59400002     5940       00       02       3
# 3  59400003     5940       00       03       4
# 4  59400004     5940       00       04       5
#
#                                             geometry
# 0  POLYGON ((140.01250 39.33333, 140.00000 39.333...
# 1  POLYGON ((140.02500 39.33333, 140.01250 39.333...
# 2  POLYGON ((140.03750 39.33333, 140.02500 39.333...
# 3  POLYGON ((140.05000 39.33333, 140.03750 39.333...
# 4  POLYGON ((140.06250 39.33333, 140.05000 39.333...

# %%
gnmdeta1 =pd.read_csv('data/tblT001100S5940.zip',encoding='cp932')
gnmdeta2 =pd.read_csv('data/tblT001100S6040.zip',encoding='cp932')

# %%
gnmdata1.head()
# Out:
#      KEY_CODE  HTKSYORI  HTKSAKI GASSAN T001100001 T001100002 T001100003
# 1  59400000.0       0.0      NaN    NaN        620        291        329  \
# 2  59400002.0       0.0      NaN    NaN         20         11          9
# 3  59400003.0       0.0      NaN    NaN         99         52         47
# 4  59400004.0       0.0      NaN    NaN         91         45         46
# 5  59400005.0       0.0      NaN    NaN        122         57         65
#
#   T001100004 T001100005 T001100006  ... T001100041 T001100042 T001100043
# 1         79         33         46  ...          7          2        183  \
# 2          0          0          0  ...          0          0          5
# 3          5          1          4  ...          1          1         27
# 4          6          3          3  ...          2          2         24
# 5         15          6          9  ...          2          2         34
#
#   T001100044 T001100045 T001100046 T001100047 T001100048 T001100049 T001100050
# ...

# %%
gnmdata1 = gnmdeta1[1:]
gnmdata2 = gnmdeta2[1:]

# %%
gnmdata1 = gnmdata1.replace("*",np.nan)
gnmdata2 = gnmdata2.replace("*",np.nan)

# %%
gnmdata = pd.concat([gnmdata1,gnmdata2])

# %%
gnmdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3120 entries, 1 to 1560
# Data columns (total 54 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   KEY_CODE    3120 non-null   float64
#  1   HTKSYORI    3120 non-null   float64
#  2   HTKSAKI     464 non-null    float64
#  3   GASSAN      382 non-null    object
#  4   T001100001  3120 non-null   object
#  5   T001100002  3120 non-null   object
#  6   T001100003  3120 non-null   object
#  7   T001100004  2656 non-null   object
#  8   T001100005  2656 non-null   object
#  9   T001100006  2656 non-null   object
#  10  T001100007  2656 non-null   object
#  11  T001100008  2656 non-null   object
#  12  T001100009  2656 non-null   object
#  13  T001100010  2656 non-null   object
#  14  T001100011  2656 non-null   object
#  15  T001100012  2656 non-null   object
#  16  T001100013  2656 non-null   object
#  17  T001100014  2656 non-null   object
#  18  T001100015  2656 non-null   object
# ...

# %%
gnmdata.columns
# Out:
# Index(['KEY_CODE', 'HTKSYORI', 'HTKSAKI', 'GASSAN', 'T001100001', 'T001100002',
#        'T001100003', 'T001100004', 'T001100005', 'T001100006', 'T001100007',
#        'T001100008', 'T001100009', 'T001100010', 'T001100011', 'T001100012',
#        'T001100013', 'T001100014', 'T001100015', 'T001100016', 'T001100017',
#        'T001100018', 'T001100019', 'T001100020', 'T001100021', 'T001100022',
#        'T001100023', 'T001100024', 'T001100025', 'T001100026', 'T001100027',
#        'T001100028', 'T001100029', 'T001100030', 'T001100031', 'T001100032',
#        'T001100033', 'T001100034', 'T001100035', 'T001100036', 'T001100037',
#        'T001100038', 'T001100039', 'T001100040', 'T001100041', 'T001100042',
#        'T001100043', 'T001100044', 'T001100045', 'T001100046', 'T001100047',
#        'T001100048', 'T001100049', 'T001100050'],
#       dtype='object')

# %%
gnmdata.columns[4:]
# Out:
# Index(['T001100001', 'T001100002', 'T001100003', 'T001100004', 'T001100005',
#        'T001100006', 'T001100007', 'T001100008', 'T001100009', 'T001100010',
#        'T001100011', 'T001100012', 'T001100013', 'T001100014', 'T001100015',
#        'T001100016', 'T001100017', 'T001100018', 'T001100019', 'T001100020',
#        'T001100021', 'T001100022', 'T001100023', 'T001100024', 'T001100025',
#        'T001100026', 'T001100027', 'T001100028', 'T001100029', 'T001100030',
#        'T001100031', 'T001100032', 'T001100033', 'T001100034', 'T001100035',
#        'T001100036', 'T001100037', 'T001100038', 'T001100039', 'T001100040',
#        'T001100041', 'T001100042', 'T001100043', 'T001100044', 'T001100045',
#        'T001100046', 'T001100047', 'T001100048', 'T001100049', 'T001100050'],
#       dtype='object')

# %%
gnmdata[gnmdata.columns[4:]].astype(float)
# Out:
#       T001100001  T001100002  T001100003  T001100004  T001100005  T001100006
# 1          241.0       112.0       129.0         9.0         5.0         4.0  \
# 2           27.0        15.0        12.0         1.0         1.0         0.0
# 3           86.0        33.0        53.0         3.0         1.0         2.0
# 4           49.0        21.0        28.0         5.0         1.0         4.0
# 5          238.0       116.0       122.0        20.0        14.0         6.0
# ...          ...         ...         ...         ...         ...         ...
# 1556        17.0         8.0         9.0         0.0         0.0         0.0
# 1557         5.0         4.0         1.0         NaN         NaN         NaN
# 1558         8.0         5.0         3.0         NaN         NaN         NaN
# 1559         8.0         3.0         5.0         0.0         0.0         0.0
# 1560         1.0         1.0         0.0         NaN         NaN         NaN
#
# ...

# %%
gnmdata[gnmdata.columns[4:]]=gnmdata[gnmdata.columns[4:]].astype(float)

# %%
gnmdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3120 entries, 1 to 1560
# Data columns (total 54 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   KEY_CODE    3120 non-null   float64
#  1   HTKSYORI    3120 non-null   float64
#  2   HTKSAKI     464 non-null    float64
#  3   GASSAN      382 non-null    object
#  4   T001100001  3120 non-null   float64
#  5   T001100002  3120 non-null   float64
#  6   T001100003  3120 non-null   float64
#  7   T001100004  2656 non-null   float64
#  8   T001100005  2656 non-null   float64
#  9   T001100006  2656 non-null   float64
#  10  T001100007  2656 non-null   float64
#  11  T001100008  2656 non-null   float64
#  12  T001100009  2656 non-null   float64
#  13  T001100010  2656 non-null   float64
#  14  T001100011  2656 non-null   float64
#  15  T001100012  2656 non-null   float64
#  16  T001100013  2656 non-null   float64
#  17  T001100014  2656 non-null   float64
# ...

# %%
gnmmesh['KEY_CODE']=gnmmesh['KEY_CODE'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 gnmmesh['KEY_CODE']=gnmmesh['KEY_CODE'].astype(float)
#
# NameError: name 'gnmmesh' is not defined
